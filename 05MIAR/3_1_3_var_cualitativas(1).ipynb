# %%
# Creación aleatoria de datos
import numpy as np
import random
random.seed(42)

# %%
nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)

nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Bachillerato' 'Master' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Doctorado' 'Grado' 'Grado'
#  'Master' 'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Grado' 'Doctorado' 'Grado'
#  'Doctorado' 'Grado' 'Grado' 'Secundaria' 'Grado' 'Secundaria' 'Master'
#  'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Master'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Grado'
#  'Master' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Master'
#  'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Doctorado' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Master' 'Master' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Grado' 'Master' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Grado' 'Grado' 'Bachillerato'
#  'Grado' 'Grado' 'Secundaria' 'Master' 'Grado' 'Bachillerato' 'Grado'
#  'Master' 'Secundaria' 'Master' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Doctorado' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Master' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Grado' 'Bachillerato' 'Master' 'Grado' 'Bachillerato' 'Master'
#  'Secundaria' 'Secundaria' 'Grado' 'Master' 'Grado' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Master' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato' 'Grado'
#  'Secundaria' 'Master' 'Secundaria' 'Master' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Grado' 'Master' 'Bachillerato'
#  'Master' 'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato' 'Grado'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Master' 'Bachillerato' 'Grado'
#  'Master' 'Grado' 'Grado' 'Secundaria' 'Secundaria' 'Grado' 'Bachillerato'
#  'Master' 'Grado' 'Doctorado' 'Secundaria' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Secundaria' 'Grado'
#  'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Grado' 'Secundaria'
#  'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Doctorado' 'Grado' 'Grado'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Master'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Doctorado' 'Secundaria'
#  'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Master' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Master' 'Grado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Secundaria' 'Master' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Bachillerato' 'Doctorado'
#  'Doctorado' 'Grado' 'Grado' 'Bachillerato' 'Doctorado' 'Secundaria'
#  'Master' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Grado'
#  'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Doctorado' 'Bachillerato' 'Grado' 'Bachillerato' 'Doctorado'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Grado'
#  'Master' 'Secundaria' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Master' 'Grado' 'Bachillerato' 'Grado' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Doctorado' 'Bachillerato' 'Grado'
#  'Doctorado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Grado' 'Doctorado' 'Doctorado' 'Master' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato' 'Secundaria'
#  'Master' 'Secundaria' 'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Secundaria' 'Master' 'Grado'
#  'Master' 'Master' 'Bachillerato' 'Master' 'Secundaria' 'Grado'
#  'Bachillerato' 'Grado' 'Master' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Doctorado' 'Master'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Master' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Master' 'Grado' 'Secundaria'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Master'
#  'Grado' 'Bachillerato' 'Secundaria' 'Master' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Grado'
#  'Grado' 'Secundaria' 'Bachillerato' 'Master' 'Secundaria' 'Bachillerato'
#  'Grado' 'Grado' 'Secundaria' 'Secundaria' 'Grado' 'Grado' 'Bachillerato'
#  'Secundaria' 'Master' 'Doctorado' 'Secundaria' 'Bachillerato' 'Grado'
#  'Secundaria' 'Grado' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Doctorado' 'Secundaria' 'Master' 'Grado' 'Bachillerato'
#  'Doctorado' 'Grado' 'Master' 'Grado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Master' 'Secundaria' 'Secundaria'
#  'Master' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Secundaria' 'Grado']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np
estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia, color='orange', edgecolor='blue', linewidth=4) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.grid()
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()
